# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
student_df = pd.read_csv(r"C:\Users\poude\Downloads\StudentsPerformance.xls")

# %%
student_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df = student_df.copy()

# %%
df is student_df
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
if {'math score','reading score','writing score'}.issubset(df.columns):
    df["avg_score"]=df[['math score','reading score','writing score']].mean(axis=1)
    plt.figure(figsize=(8,5))
    sns.histplot(df['avg_score'],kde=True,color="blue")
    plt.title("DISTRIBUTION OF AVERAGE SCORE")
    plt.show()

# %% [markdown]
# # Count plot for categorical columns

# %%
cat_cols= df.select_dtypes(include=['object']).columns
for col in cat_cols:
    plt.figure(figsize=(8,5))
    sns.countplot(data=df , x = col , palette='viridis')
    plt.title(f"count plot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\poude\AppData\Local\Temp\ipykernel_26888\1988733819.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df , x = col , palette='viridis')
# C:\Users\poude\AppData\Local\Temp\ipykernel_26888\1988733819.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df , x = col , palette='viridis')
# C:\Users\poude\AppData\Local\Temp\ipykernel_26888\1988733819.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df , x = col , palette='viridis')
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# avg_score                      0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='gender', y='avg_score',data=df)
plt.title('avg score by gender')
plt.show()

# %%
import numpy as np
plt.figure(figsize=(8,4))
sns.barplot(x="race/ethnicity", y="avg_score", data=df, errorbar=None)
plt.title("Average Score by Race/Ethnicity")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="lunch", y="avg_score", data=df)
plt.title("Average Score by Lunch Type")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="test preparation course", y="avg_score", data=df)
plt.title("Average Score by Test Preparation Course")
plt.show()

# %%
cat_cols
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
# count plot already done repeated
for cols in cat_cols:
    print(f"The value count of column {cols} is :")
    counts=df[cols].value_counts()
    counts_per = df[cols].value_counts(normalize=True)*100
    summary = pd.DataFrame({
        'count': counts,
        'percentage':counts_per
    })
    print(summary)
    print(f"counts plots for -- {cols}")
    sns.countplot(data=df, x=cols)
    plt.title(f'Distribution of {cols}')
    plt.xlabel(cols)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# The value count of column gender is :
#         count  percentage
# gender
# female    518        51.8
# male      482        48.2
# counts plots for -- gender
# The value count of column race/ethnicity is :
#                 count  percentage
# race/ethnicity
# group C           319        31.9
# group D           262        26.2
# group B           190        19.0
# group E           140        14.0
# group A            89         8.9
# counts plots for -- race/ethnicity
# The value count of column parental level of education is :
#                              count  percentage
# parental level of education
# some college                   226        22.6
# associate's degree             222        22.2
# high school                    196        19.6
# some high school               179        17.9
# bachelor's degree              118        11.8
# master's degree                 59         5.9
# counts plots for -- parental level of education
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Gender vs Avg Score
plt.figure(figsize=(6,4))
sns.boxplot(x="gender", y="avg_score", data=df)
plt.title("Gender vs Avg Score")
plt.show()

# Race/Ethnicity vs Avg Score
plt.figure(figsize=(7,4))
sns.boxplot(x="race/ethnicity", y="avg_score", data=df)
plt.title("Race/Ethnicity vs Avg Score")
plt.show()

# Parental Education vs Avg Score
plt.figure(figsize=(10,5))
sns.boxplot(x="parental level of education", y="avg_score", data=df)
plt.xticks(rotation=45)
plt.title("Parental Education vs Avg Score")
plt.show()

# Test Preparation Course vs Avg Score
plt.figure(figsize=(6,4))
sns.boxplot(x="test preparation course", y="avg_score", data=df)
plt.title("Test Prep Course vs Avg Score")
plt.show()

# Test Preparation Course vs Avg Score
plt.figure(figsize=(6,4))
sns.boxplot(x="lunch", y="avg_score", data=df)
plt.title("lunch vs Avg Score")
plt.show()

# %%
df.groupby("gender")["avg_score"].mean()
# Out:
# gender
# female    69.569498
# male      65.837483
# Name: avg_score, dtype: float64

# %%
df.groupby("race/ethnicity")["avg_score"].mean()
# Out:
# race/ethnicity
# group A    62.992509
# group B    65.468421
# group C    67.131661
# group D    69.179389
# group E    72.752381
# Name: avg_score, dtype: float64

# %%
df.groupby("parental level of education")["avg_score"].mean()
# Out:
# parental level of education
# associate's degree    69.569069
# bachelor's degree     71.923729
# high school           63.096939
# master's degree       73.598870
# some college          68.476401
# some high school      65.108007
# Name: avg_score, dtype: float64

# %%
df.groupby("test preparation course")["avg_score"].mean()
# Out:
# test preparation course
# completed    72.669460
# none         65.038941
# Name: avg_score, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[["math score", "reading score", "writing score", "avg_score"]].corr(), 
            annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
sns.pairplot(df[["math score", "reading score", "writing score", "avg_score"]])
plt.show()

# %%
df_clean = df.copy()

# %%
df_clean['gender'] = df_clean['gender'].map({
    'male':0, 
    'female':1
})

# %%
df_clean['test preparation course'] = df_clean['test preparation course'].map({
    'none':0,
    'completed':1
})

# %%
df_clean['lunch'] = df_clean['lunch'].map({
    'standard':0,
    'free/reduced':1
})

# %%
df_clean = pd.get_dummies(df_clean,columns=['race/ethnicity'], drop_first=True)
df_clean = pd.get_dummies(df_clean,columns=['parental level of education'], drop_first=True)

# %%
x = df_clean.drop(["math score", "reading score", "writing score"],axis=1)
y = df_clean['avg_score']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# %%
cat_cols
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
cat_cols_x = x.select_dtypes(include=['object']).columns
num_cols_x = x.select_dtypes(exclude=['object']).columns

# %% [markdown]
# preprocessing

# %%
preprocessor = ColumnTransformer([
    ('num','passthrough',num_cols_x),
    ('cat',OneHotEncoder(drop='first', handle_unknown='ignore'),cat_cols_x)
])

# %% [markdown]
# models

# %%
models = {
    'LinearRegression': LinearRegression(),
    'DecisionTreeRegressor': DecisionTreeRegressor(random_state=42), 
    'RandomForestRegressor': RandomForestRegressor(n_estimators=100,random_state=42), 
    'GradientBoostingRegressor': GradientBoostingRegressor(random_state=42), 
    'SVR': SVR(kernel='rbf')
}

# %%
x_train , x_test , y_train ,y_test = train_test_split(x , y , test_size=0.2, random_state=42)

# %%
results = []

for name , model in models.items(): 
    pipe = Pipeline([
        ('preprocessor',preprocessor), 
        ('scaler', StandardScaler() if name == 'SVR' else 'passthrough'),
        ('model', model)
    ])
    pipe.fit(x_train,y_train)
    y_pred = pipe.predict(x_test)

    # mean square for comp and r2 for better visualize comp marices for regression accuracy for classification
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test,y_pred)

    results.append({
        'Model':name, 
        'mean square error': mse, 
        'root mean square error': rmse, 
        'R2 score': r2
    })

results_df = pd.DataFrame(results).sort_values(by= 'R2 score',ascending= False)
print(results_df)

# bar plot of r2 
plt.figure(figsize=(16,9))
sns.barplot(data=results_df, x= 'Model', y = 'R2 score', palette='viridis')
plt.title('Model comparison of R² score')
plt.show()
# Out:
#                        Model  mean square error  root mean square error  \
# 0           LinearRegression       2.505422e-29            5.005419e-15
# 3  GradientBoostingRegressor       4.629197e-01            6.803820e-01
# 1      DecisionTreeRegressor       4.883333e-01            6.988085e-01
# 2      RandomForestRegressor       8.748413e-01            9.353295e-01
# 4                        SVR       3.299366e+01            5.744011e+00
#
#    R2 score
# 0  1.000000
# 3  0.997841
# 1  0.997722
# 2  0.995919
# 4  0.846088
# C:\Users\poude\AppData\Local\Temp\ipykernel_26888\877591179.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=results_df, x= 'Model', y = 'R2 score', palette='viridis')

# %%
# Encode categorical temporarily for correlation
encoded_df = pd.get_dummies(df.drop(columns=["math score","reading score","writing score"]), 
                            drop_first=True)

plt.figure(figsize=(12,8))
sns.heatmap(encoded_df.corr()[["avg_score"]].sort_values(by="avg_score", ascending=False),
            annot=True, cmap="coolwarm")
plt.title("Correlation of Features with Avg Score")
plt.show()
